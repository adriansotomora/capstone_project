# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
clients = pd.read_csv("data/processed/clients.csv")
clients
# Out:
#        client_id       city channel  promotor_id  frequency  efficiency  \
# 0      100006690     Madrid      AR    275609911        2.0    0.916667
# 1      100008050  Barcelona      AR    368568690        1.0   16.333333
# 2      100042162  Barcelona      HR    455263770        1.0    0.318182
# 3      100046227  Barcelona      AR    454554895        4.0    2.000000
# 4      100125158      Cadiz      HR    483340469        3.0    2.500000
# ...          ...        ...     ...          ...        ...         ...
# 41945  999934164  Barcelona      HR    480416490        2.0    2.555556
# 41946  999940211  Barcelona      AR    908993212        1.0   16.333333
# 41947  999940578     Madrid      AR    275609911        1.0    0.590909
# 41948  999941988     Madrid      AR    677360818        3.0    1.500000
# 41949  999976985  Barcelona      HR    996963848        3.0    2.636364
#
#        efficiency_scaled  total_orders  total_volume  total_income  \
# 0               0.056122            22      1658.706       1494.53
# 1               1.500000            14      3982.000       1905.59
# 2               0.019481            14      1812.850       2243.30
# 3               0.122449            16      4590.180       2273.12
# 4               0.153061            25      1266.500       2204.24
# ...                  ...           ...           ...           ...
# 41945           0.156463            23       691.000        785.30
# 41946           1.500000             3       557.820        260.55
# 41947           0.036178            13      1101.524       1044.61
# 41948           0.091837            36      5415.150       3828.31
# 41949           0.161410            29      1743.000       6988.48
#
#        total_cost  total_profit  median_ticket  median_ticket_min  \
# 0             880        614.53         60.990              33.00
# 1             140       1765.59        132.370              66.96
# 2             980       1263.30        128.125              29.62
# 3             640       1633.12        132.640              83.21
# 4             625       1579.24         85.810              26.15
# ...           ...           ...            ...                ...
# 41945         575        210.30         38.330              25.55
# 41946          30        230.55         76.430              75.02
# 41947         520        524.61         68.260              50.03
# 41948        1410       2418.31        102.840               0.00
# 41949         725       6263.48        211.830              25.25
#
#        median_ticket_max  median_ticket_std  median_promotor_visits  \
# 0                 123.89          22.262210                     2.0
# 1                 187.10          38.756311                     0.0
# 2                 220.82          49.543046                     4.0
# 3                 276.33          48.602430                     2.0
# 4                 173.95          41.511632                     1.0
# ...                  ...                ...                     ...
# 41945              55.23           9.544566                     1.0
# 41946             109.10          19.281958                     0.0
# 41947             183.56          36.563004                     2.0
# 41948             188.96          41.406391                     2.0
# 41949             407.92         106.655742                     1.0
#
#        total_promotor_visits  median_promotor_calls  total_promotor_calls  \
# 0                       24.0                    0.0                   0.0
# 1                        0.0                    2.0                  20.0
# 2                       44.0                    0.0                   0.0
# 3                        8.0                    2.0                   8.0
# 4                       10.0                    0.0                   0.0
# ...                      ...                    ...                   ...
# 41945                    9.0                    3.0                  27.0
# 41946                    0.0                    0.0                   0.0
# 41947                   22.0                    0.0                   0.0
# 41948                   24.0                    2.0                  24.0
# 41949                   11.0                    0.0                   0.0
#
#                         class  zero_visit_flag  avg_orders_per_month  \
# 0       LowTicket_Inefficient            False              1.833333
# 1        HighTicket_Efficient             True              1.166667
# 2      HighTicket_Inefficient            False              1.166667
# 3        HighTicket_Efficient            False              1.333333
# 4        HighTicket_Efficient            False              2.083333
# ...                       ...              ...                   ...
# 41945     LowTicket_Efficient            False              1.916667
# 41946     LowTicket_Efficient             True              0.250000
# 41947   LowTicket_Inefficient            False              1.083333
# 41948    HighTicket_Efficient            False              3.000000
# 41949    HighTicket_Efficient            False              2.416667
#
#        avg_visits_per_month  visit_order_gap  inefficiency_cost  \
# 0                  2.000000         0.166667               2.50
# 1                  0.000000        -1.166667             -17.50
# 2                  3.666667         2.500000              37.50
# 3                  0.666667        -0.666667             -10.00
# 4                  0.833333        -1.250000             -18.75
# ...                     ...              ...                ...
# 41945              0.750000        -1.166667             -17.50
# 41946              0.000000        -0.250000              -3.75
# 41947              1.833333         0.750000              11.25
# 41948              2.000000        -1.000000             -15.00
# 41949              0.916667        -1.500000             -22.50
#
#        profit_per_visit  opportunity_cost
# 0             25.605417          4.267569
# 1              0.000000         -0.000000
# 2             28.711364         71.778409
# 3            204.140000       -136.093333
# 4            157.924000       -197.405000
# ...                 ...               ...
# 41945         23.366667        -27.261111
# 41946          0.000000         -0.000000
# 41947         23.845909         17.884432
# 41948        100.762917       -100.762917
# 41949        569.407273       -854.110909
#
# [41950 rows x 28 columns]

# %%
clients[clients['efficiency'] > 1]
# Out:
#        client_id       city channel  promotor_id  frequency  efficiency  \
# 1      100008050  Barcelona      AR    368568690        1.0   16.333333
# 3      100046227  Barcelona      AR    454554895        4.0    2.000000
# 4      100125158      Cadiz      HR    483340469        3.0    2.500000
# 5      100137028     Murcia      AR    733727842        2.0   16.333333
# 6      100163544  Castellon      HR    988985367        2.0   16.333333
# ...          ...        ...     ...          ...        ...         ...
# 41944  999924010     Murcia      HR    385265118        5.0    2.291667
# 41945  999934164  Barcelona      HR    480416490        2.0    2.555556
# 41946  999940211  Barcelona      AR    908993212        1.0   16.333333
# 41948  999941988     Madrid      AR    677360818        3.0    1.500000
# 41949  999976985  Barcelona      HR    996963848        3.0    2.636364
#
#        efficiency_scaled  total_orders  total_volume  total_income  \
# 1               1.500000            14      3982.000       1905.59
# 3               0.122449            16      4590.180       2273.12
# 4               0.153061            25      1266.500       2204.24
# 5               1.500000            23      3930.000       1463.61
# 6               1.500000            14       867.174       1799.91
# ...                  ...           ...           ...           ...
# 41944           0.140306            55      8668.200      10274.38
# 41945           0.156463            23       691.000        785.30
# 41946           1.500000             3       557.820        260.55
# 41948           0.091837            36      5415.150       3828.31
# 41949           0.161410            29      1743.000       6988.48
#
#        total_cost  total_profit  median_ticket  median_ticket_min  \
# 1             140       1765.59         132.37              66.96
# 3             640       1633.12         132.64              83.21
# 4             625       1579.24          85.81              26.15
# 5             230       1233.61          61.07              52.72
# 6             140       1659.91         114.88              22.82
# ...           ...           ...            ...                ...
# 41944        2200       8074.38         190.76              12.53
# 41945         575        210.30          38.33              25.55
# 41946          30        230.55          76.43              75.02
# 41948        1410       2418.31         102.84               0.00
# 41949         725       6263.48         211.83              25.25
#
#        median_ticket_max  median_ticket_std  median_promotor_visits  \
# 1                 187.10          38.756311                     0.0
# 3                 276.33          48.602430                     2.0
# 4                 173.95          41.511632                     1.0
# 5                  70.31           6.678725                     0.0
# 6                 323.57          75.344392                     0.0
# ...                  ...                ...                     ...
# 41944             290.63          45.310879                     2.0
# 41945              55.23           9.544566                     1.0
# 41946             109.10          19.281958                     0.0
# 41948             188.96          41.406391                     2.0
# 41949             407.92         106.655742                     1.0
#
#        total_promotor_visits  median_promotor_calls  total_promotor_calls  \
# 1                        0.0                    2.0                  20.0
# 3                        8.0                    2.0                   8.0
# 4                       10.0                    0.0                   0.0
# 5                        0.0                    2.0                  24.0
# 6                        0.0                    0.0                   0.0
# ...                      ...                    ...                   ...
# 41944                   24.0                    2.0                  24.0
# 41945                    9.0                    3.0                  27.0
# 41946                    0.0                    0.0                   0.0
# 41948                   24.0                    2.0                  24.0
# 41949                   11.0                    0.0                   0.0
#
#                       class  zero_visit_flag  avg_orders_per_month  \
# 1      HighTicket_Efficient             True              1.166667
# 3      HighTicket_Efficient            False              1.333333
# 4      HighTicket_Efficient            False              2.083333
# 5       LowTicket_Efficient             True              1.916667
# 6      HighTicket_Efficient             True              1.166667
# ...                     ...              ...                   ...
# 41944  HighTicket_Efficient            False              4.583333
# 41945   LowTicket_Efficient            False              1.916667
# 41946   LowTicket_Efficient             True              0.250000
# 41948  HighTicket_Efficient            False              3.000000
# 41949  HighTicket_Efficient            False              2.416667
#
#        avg_visits_per_month  visit_order_gap  inefficiency_cost  \
# 1                  0.000000        -1.166667             -17.50
# 3                  0.666667        -0.666667             -10.00
# 4                  0.833333        -1.250000             -18.75
# 5                  0.000000        -1.916667             -28.75
# 6                  0.000000        -1.166667             -17.50
# ...                     ...              ...                ...
# 41944              2.000000        -2.583333             -38.75
# 41945              0.750000        -1.166667             -17.50
# 41946              0.000000        -0.250000              -3.75
# 41948              2.000000        -1.000000             -15.00
# 41949              0.916667        -1.500000             -22.50
#
#        profit_per_visit  opportunity_cost
# 1              0.000000         -0.000000
# 3            204.140000       -136.093333
# 4            157.924000       -197.405000
# 5              0.000000         -0.000000
# 6              0.000000         -0.000000
# ...                 ...               ...
# 41944        336.432500       -869.117292
# 41945         23.366667        -27.261111
# 41946          0.000000         -0.000000
# 41948        100.762917       -100.762917
# 41949        569.407273       -854.110909
#
# [27323 rows x 28 columns]

# %% [markdown]
# ## Clustering

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Select relevant behavioral features (you can adjust as needed)
features_for_clustering = [
    'total_volume', 'total_income', 'total_profit',
    'median_ticket', 'median_ticket_std',
    'median_promotor_calls', 'total_promotor_calls',
    'profit_per_visit', 'visit_order_gap', 'total_promotor_visits', 'avg_orders_per_month', 'efficiency'
]

# Step 2: Prepare and scale the data
X = clients[features_for_clustering].copy().fillna(0)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Apply KMeans
k = 5  # Choose number of clusters
kmeans = KMeans(n_clusters=k, random_state=42)
clients['cluster'] = kmeans.fit_predict(X_scaled)

# Step 4: Visualize clusters with PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
clients['pca_1'] = X_pca[:, 0]
clients['pca_2'] = X_pca[:, 1]

plt.figure(figsize=(10, 6))
sns.scatterplot(data=clients, x='pca_1', y='pca_2', hue='cluster', palette='Set2')
plt.title('Client Clusters (PCA Projection)')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
# Summary of clusters
cluster_summary = clients.groupby('cluster')[features_for_clustering].mean().round(2)
display(cluster_summary)
# Out:
#          total_volume  total_income  total_profit  median_ticket  \
# cluster
# 0             4958.37       4847.39       3844.76         112.13
# 1             6241.24       7353.65       4237.39         147.90
# 2             1663.26       1321.70        943.09         105.75
# 3           390514.11     230628.82     227056.20        3489.94
# 4            64332.92      50586.84      47819.16        1181.54
#
#          median_ticket_std  median_promotor_calls  total_promotor_calls  \
# cluster
# 0                    49.17                   2.68                 29.59
# 1                    70.96                   0.04                  0.43
# 2                    46.22                   0.40                  2.59
# 3                  2106.15                   1.25                 14.85
# 4                   989.36                   0.97                 11.16
#
#          profit_per_visit  visit_order_gap  total_promotor_visits  \
# cluster
# 0                  135.36            -2.17                  11.10
# 1                  100.69             0.08                  44.95
# 2                   72.50            -0.25                   9.01
# 3                 3523.72            -3.77                  26.09
# 4                 1566.28            -1.90                  25.09
#
#          avg_orders_per_month  efficiency
# cluster
# 0                        3.10        8.26
# 1                        3.66        1.02
# 2                        1.00        4.75
# 3                        5.95        8.33
# 4                        3.99        5.78

# %%
# Assuming 'class' and 'cluster' columns exist in `clients`
cluster_class_counts = clients.groupby(['class', 'cluster']).size().unstack(fill_value=0)

# Display the count table
print(cluster_class_counts)
# Out:
# cluster                    0     1     2   3    4
# class
# HighTicket_Efficient    5306  3252  8302  42  304
# HighTicket_Inefficient    44  2292  3825   2   48
# LowTicket_Efficient     4155   705  8953   0    3
# LowTicket_Inefficient     41  1273  3403   0    0

# %%
#average efficiency per cluster

efficiency_per_cluster = clients.groupby('cluster')['efficiency'].mean().round(2)
efficiency_per_cluster
# Out:
# cluster
# 0    8.26
# 1    1.02
# 2    4.75
# 3    8.33
# 4    5.78
# Name: efficiency, dtype: float64

# %% [markdown]
# ## Model

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor, plot_importance
import matplotlib.pyplot as plt

# Define features and target
target = 'avg_visits_per_month'
features = [
    "total_volume", "total_income", "total_profit", "median_ticket", 
    "median_ticket_std", "median_promotor_calls", "total_promotor_calls", 
    "profit_per_visit", "visit_order_gap"
]

# Store predictions per cluster
all_cluster_predictions = []

# Iterate over each cluster
for cluster in clients['cluster'].unique():
    cluster_data = clients[clients['cluster'] == cluster]

    # Split efficient and inefficient clients
    efficient_data = cluster_data[cluster_data['efficiency'] >= 1]
    inefficient_data = cluster_data[cluster_data['efficiency'] < 1]

    # Skip cluster if insufficient data
    if len(efficient_data) < 10 or len(inefficient_data) == 0:
        print(f"❌ Skipping cluster {cluster}: Not enough data")
        continue

    # Prepare features
    X_train = efficient_data[features].fillna(0)
    y_train = efficient_data[target]
    X_test = inefficient_data[features].fillna(0)

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=features, index=X_train.index)
    X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=features, index=X_test.index)

    # Train model
    model = XGBRegressor(objective="reg:squarederror", random_state=42)
    model.fit(X_train_scaled, y_train)

    # Evaluate only on training data (efficient clients)
    y_train_pred = model.predict(X_train_scaled)
    rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    r2 = r2_score(y_train, y_train_pred)
    print(f"\n📊 Cluster {cluster} — RMSE (Efficient): {rmse:.2f} | R²: {r2:.2f}")

    # Show feature importance
    plt.figure(figsize=(8, 5))
    plot_importance(model, importance_type='gain', title=f'Feature Importance — Cluster {cluster}')
    plt.tight_layout()
    plt.show()

    # Predict for inefficient clients only
    y_pred = model.predict(X_test_scaled)
    inefficient_data = inefficient_data.copy()
    inefficient_data["predicted_avg_visits_per_month"] = y_pred
    all_cluster_predictions.append(inefficient_data)

# Combine predictions for all inefficient clients
final_predictions_df = pd.concat(all_cluster_predictions)

# Compute and show average actual vs predicted visits per cluster
avg_actual = final_predictions_df.groupby("cluster")["avg_visits_per_month"].mean().round(2)
avg_predicted = final_predictions_df.groupby("cluster")["predicted_avg_visits_per_month"].mean().round(2)

avg_predicted_visits = pd.DataFrame({
    "avg_visits_per_month (inefficient)": avg_actual,
    "predicted_avg_visits_per_month": avg_predicted
}).reset_index()

print("\n🔍 Comparison of actual vs. predicted visits (inefficient clients only):")
print(avg_predicted_visits)
# Sample output
print(final_predictions_df[['client_id', 'cluster', 'avg_visits_per_month', 'predicted_avg_visits_per_month']].head())
# Out:
# 📊 Cluster 2 — RMSE (Efficient): 0.02 | R²: 1.00
# 📊 Cluster 0 — RMSE (Efficient): 0.01 | R²: 1.00
# 📊 Cluster 1 — RMSE (Efficient): 0.02 | R²: 1.00
# 📊 Cluster 4 — RMSE (Efficient): 0.00 | R²: 1.00
# 📊 Cluster 3 — RMSE (Efficient): 0.00 | R²: 1.00
# 🔍 Comparison of actual vs. predicted visits (inefficient clients only):
#    cluster  avg_visits_per_month (inefficient)  predicted_avg_visits_per_month
# 0        0                                3.21                            2.55
# 1        1                                3.93                            3.40
# 2        2                                1.29                            1.04
# 3        3                                3.83                            1.00
# 4        4                                4.16                            3.96
#     client_id  cluster  avg_visits_per_month  predicted_avg_visits_per_month
# 0   100006690        2              2.000000                        1.933421
# 9   100179704        2              0.166667                        0.069144
# 14  100234953        2              2.000000                        1.919589
# 15  100262932        2              2.000000                        1.645116
# 23  100432026        2              2.000000                        1.950055

# %%
# 📊 Average actual and predicted visits per cluster (only for inefficient clients)

# Group by cluster and compute mean values
avg_visits_per_cluster = final_predictions_df.groupby('cluster')['avg_visits_per_month'].mean()
predicted_visits_per_cluster = final_predictions_df.groupby('cluster')['predicted_avg_visits_per_month'].mean()

# Calculate percentage change: (predicted - actual) / actual * 100
percentage_change = ((predicted_visits_per_cluster - avg_visits_per_cluster) / avg_visits_per_cluster * 100).round(2)

# Combine results into a single DataFrame
avg_predicted_visits = pd.DataFrame({
    'avg_visits_per_month (inefficient)': avg_visits_per_cluster.round(2),
    'predicted_avg_visits_per_month': predicted_visits_per_cluster.round(2),
    'percentage_change (%)': percentage_change
}).reset_index()

# Display results
print("🔍 Comparison of actual vs. predicted visits (inefficient clients only):")
print(avg_predicted_visits)
# Out:
# 🔍 Comparison of actual vs. predicted visits (inefficient clients only):
#    cluster  avg_visits_per_month (inefficient)  \
# 0        0                                3.21
# 1        1                                3.93
# 2        2                                1.29
# 3        3                                3.83
# 4        4                                4.16
#
#    predicted_avg_visits_per_month  percentage_change (%)
# 0                            2.55                 -20.45
# 1                            3.40                 -13.55
# 2                            1.04                 -19.27
# 3                            1.00                 -73.97
# 4                            3.96                  -4.93

# %%
# sum of saved visits

total_saved_visits = ((final_predictions_df['avg_visits_per_month'] - final_predictions_df['predicted_avg_visits_per_month']).sum()) * 12

total_saved_visits
# Out:
# 45126.10445913765

# %%
# saved cost of saved visits

total_saved_cost = total_saved_visits * 15

total_saved_cost
# Out:
# 676891.5668870647

# %% [markdown]
# ## Impact on income

# %%
# Group by cluster and compute correlation between total_promotor_visits and total_income
correlation_by_cluster = clients.groupby('cluster').apply(
    lambda df: df['total_promotor_visits'].corr(df['total_income'])
).reset_index(name='correlation')

# Display the correlation per cluster
print(correlation_by_cluster)
# Out:
#    cluster  correlation
# 0        0     0.245720
# 1        1     0.301314
# 2        2     0.375025
# 3        3     0.118007
# 4        4     0.469160
# /var/folders/lv/gn03ly3n62g1g9qqycdm72800000gn/T/ipykernel_26458/504847575.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   correlation_by_cluster = clients.groupby('cluster').apply(

# %% [markdown]
# 	•	⚠️ Cluster 4: High correlation and low reduction in visits (only -4.93%) → you preserved high-value relationships.
# 	•	✅ Cluster 3: Lowest correlation → most aggressive reduction. Logical and aligned with the business objective.
# 	•	💡 Business Insight: The model implicitly prioritizes cost efficiency while protecting income streams.
